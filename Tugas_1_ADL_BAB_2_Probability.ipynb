# %% [markdown]
# 2.6.1. Basic Probability Theory

# %%
# %matplotlib inline
import torch
from torch.distributions import multinomial
from d2l import torch as d2l

# %%
#The distribution that assigns probabilities to a number of discrete choices
#is called the multinomial distribution.
fair_probs = torch.ones([6]) / 6
print(fair_probs)
multinomial.Multinomial(1, fair_probs).sample() #Ini roll 1x
# Out:
# tensor([0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667])
# tensor([0., 0., 0., 1., 0., 0.])

# %%
multinomial.Multinomial(10, fair_probs).sample() #Ini roll 10x
# Out:
# tensor([0., 2., 4., 2., 0., 2.])

# %%
# Store the results as 32-bit floats for division
counts = multinomial.Multinomial(1000, fair_probs).sample()
counts / 1000  # Relative frequency as the estimate
# Out:
# tensor([0.1790, 0.1630, 0.1640, 0.1620, 0.1460, 0.1860])

# %% [markdown]
# masing-masing hasilnya mendekati 0.167 (true probability)

# %%
#INI MASIH ERROR
import d2l
counts = multinomial.Multinomial(10, fair_probs).sample((500,))
cum_counts = counts.cumsum(dim=0)
estimates = cum_counts / cum_counts.sum(dim=1, keepdims=True)

d2l.set_figsize((6, 4.5))
for i in range(6):
    d2l.plt.plot(estimates[:, i].numpy(),
                 label=("P(die=" + str(i + 1) + ")"))
d2l.plt.axhline(y=0.167, color='black', linestyle='dashed')
d2l.plt.gca().set_xlabel('Groups of experiments')
d2l.plt.gca().set_ylabel('Estimated probability')
d2l.plt.legend();

# %% [markdown]
# Harusnya gambarnya kaya gini:
# ![d2l Probability.jpg](data:image/jpeg;base64,...)
